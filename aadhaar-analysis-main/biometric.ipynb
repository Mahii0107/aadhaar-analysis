# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
bio1=pd.read_csv("api_data_aadhar_biometric_0_500000.csv")

# %%
bio2=pd.read_csv("api_data_aadhar_biometric_500000_1000000.csv")

# %%
bio3=pd.read_csv("api_data_aadhar_biometric_1000000_1500000.csv")

# %%
bio4=pd.read_csv("api_data_aadhar_biometric_1500000_1861108.csv")

# %%
bio_combined=pd.concat([bio1,bio2,bio3,bio4],ignore_index=True)

# %%
df=bio_combined.copy()

# %%
df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
df.shape
# Out:
# (1861108, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1861108 entries, 0 to 1861107
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          object
#  1   state         object
#  2   district      object
#  3   pincode       int64
#  4   bio_age_5_17  int64
#  5   bio_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 85.2+ MB

# %%
df.describe()
# Out:
#             pincode  bio_age_5_17   bio_age_17_
# count  1.861108e+06  1.861108e+06  1.861108e+06
# mean   5.217612e+05  1.839058e+01  1.909413e+01
# std    1.981627e+05  8.370421e+01  8.806502e+01
# min    1.100010e+05  0.000000e+00  0.000000e+00
# 25%    3.911750e+05  1.000000e+00  1.000000e+00
# 50%    5.224010e+05  3.000000e+00  4.000000e+00
# 75%    6.866362e+05  1.100000e+01  1.000000e+01
# max    8.554560e+05  8.002000e+03  7.625000e+03

# %%
df.isnull().sum()
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(94896)

# %%
df[df.duplicated()]
# Out:
#                date           state    district  pincode  bio_age_5_17  \
# 110000   01-09-2025    Chhattisgarh   Kondagaon   494229             0
# 110001   01-09-2025    Chhattisgarh   Kondagaon   494230             1
# 110002   01-09-2025    Chhattisgarh       Korba   495119             5
# 110003   01-09-2025    Chhattisgarh       Korba   495446             0
# 110004   01-09-2025    Chhattisgarh       Korba   495674            10
# ...             ...             ...         ...      ...           ...
# 1860707  29-12-2025  Andhra Pradesh    Prakasam   523327             3
# 1860708  29-12-2025  Andhra Pradesh    Prakasam   523368             2
# 1860709  29-12-2025  Andhra Pradesh    Prakasam   523370             1
# 1860710  29-12-2025  Andhra Pradesh    Prakasam   523371             2
# 1860711  29-12-2025  Andhra Pradesh  Rangareddi   500005             2
#
#          bio_age_17_
# 110000             1
# 110001             0
# 110002            35
# 110003            16
# 110004            34
# ...              ...
# 1860707            7
# 1860708            3
# 1860709            1
# 1860710            1
# 1860711            1
#
# [94896 rows x 6 columns]

# %%
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#                date              state        district  pincode  bio_age_5_17  \
# 0        01-03-2025            Haryana    Mahendragarh   123029           280
# 1        01-03-2025              Bihar       Madhepura   852121           144
# 2        01-03-2025  Jammu and Kashmir           Punch   185101           643
# 3        01-03-2025              Bihar         Bhojpur   802158           256
# 4        01-03-2025         Tamil Nadu         Madurai   625514           271
# ...             ...                ...             ...      ...           ...
# 1766207  29-12-2025        West Bengal  Uttar Dinajpur   733201             4
# 1766208  29-12-2025        West Bengal  Uttar Dinajpur   733213             0
# 1766209  29-12-2025        West Bengal  West Midnapore   721304             0
# 1766210  29-12-2025        West Bengal  West Midnapore   721451             2
# 1766211  29-12-2025        West Bengal  West Midnapore   721457             0
#
#          bio_age_17_
# 0                577
# 1                369
# 2               1091
# 3                980
# 4                815
# ...              ...
# 1766207            9
# 1766208            1
# 1766209            3
# 1766210            0
# 1766211            1
#
# [1766212 rows x 6 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1766212, 6)

# %%
(df == "").sum()
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64

# %%
(df.astype(str).apply(lambda x: x.str.strip() == "").sum())
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64

# %%
df[df["pincode"].astype(str).str.len() != 6]   # no invalid pincodes.
# Out:
# Empty DataFrame
# Columns: [date, state, district, pincode, bio_age_5_17, bio_age_17_]
# Index: []

# %%
df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')
df
# Out:
#               date              state        district  pincode  bio_age_5_17  \
# 0       2025-03-01            Haryana    Mahendragarh   123029           280
# 1       2025-03-01              Bihar       Madhepura   852121           144
# 2       2025-03-01  Jammu and Kashmir           Punch   185101           643
# 3       2025-03-01              Bihar         Bhojpur   802158           256
# 4       2025-03-01         Tamil Nadu         Madurai   625514           271
# ...            ...                ...             ...      ...           ...
# 1766207 2025-12-29        West Bengal  Uttar Dinajpur   733201             4
# 1766208 2025-12-29        West Bengal  Uttar Dinajpur   733213             0
# 1766209 2025-12-29        West Bengal  West Midnapore   721304             0
# 1766210 2025-12-29        West Bengal  West Midnapore   721451             2
# 1766211 2025-12-29        West Bengal  West Midnapore   721457             0
#
#          bio_age_17_
# 0                577
# 1                369
# 2               1091
# 3                980
# 4                815
# ...              ...
# 1766207            9
# 1766208            1
# 1766209            3
# 1766210            0
# 1766211            1
#
# [1766212 rows x 6 columns]

# %%
df["state"].value_counts()
# Out:
# state
# Tamil Nadu                                  174934
# Andhra Pradesh                              160202
# Uttar Pradesh                               147138
# Maharashtra                                 143609
# Karnataka                                   135780
# West Bengal                                 125274
# Kerala                                       93951
# Gujarat                                      84630
# Odisha                                       83177
# Bihar                                        78078
# Telangana                                    77850
# Rajasthan                                    76698
# Madhya Pradesh                               66020
# Punjab                                       46414
# Assam                                        44418
# Jharkhand                                    35054
# Chhattisgarh                                 30048
# Himachal Pradesh                             28723
# Haryana                                      25083
# Uttarakhand                                  21433
# Jammu and Kashmir                            18597
# Orissa                                       12767
# Delhi                                         8784
# Tripura                                       7949
# Manipur                                       6252
# Goa                                           5105
# Meghalaya                                     4016
# Arunachal Pradesh                             3957
# Nagaland                                      3666
# Mizoram                                       3217
# Puducherry                                    2535
# Sikkim                                        2298
# Pondicherry                                   2240
# Chandigarh                                    1576
# Andaman and Nicobar Islands                   1190
# Ladakh                                         688
# Lakshadweep                                    525
# Andaman & Nicobar Islands                      502
# Daman and Diu                                  394
# Jammu & Kashmir                                346
# Dadra and Nagar Haveli                         310
# Daman & Diu                                    252
# Dadra and Nagar Haveli and Daman and Diu       214
# Dadra & Nagar Haveli                            92
# West Bangal                                     47
# WEST BENGAL                                     31
# andhra pradesh                                  30
# ODISHA                                          25
# West  Bengal                                    23
# Westbengal                                      18
# West bengal                                     17
# odisha                                          15
# WESTBENGAL                                      11
# Chhatisgarh                                      5
# Uttaranchal                                      2
# west Bengal                                      1
# Tamilnadu                                        1
# Name: count, dtype: int64

# %%
df['state_clean'] = df['state'].str.lower().str.strip().str.replace(r'[^a-z]', '', regex=True)

# %%
df.head()
# Out:
#         date              state      district  pincode  bio_age_5_17  \
# 0 2025-03-01            Haryana  Mahendragarh   123029           280
# 1 2025-03-01              Bihar     Madhepura   852121           144
# 2 2025-03-01  Jammu and Kashmir         Punch   185101           643
# 3 2025-03-01              Bihar       Bhojpur   802158           256
# 4 2025-03-01         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_      state_clean
# 0          577          haryana
# 1          369            bihar
# 2         1091  jammuandkashmir
# 3          980            bihar
# 4          815        tamilnadu

# %%
df["district"].value_counts()
# Out:
# district
# Pune                 11068
# Thrissur             10594
# North 24 Parganas    10128
# Barddhaman           10079
# East Godavari         9872
#                      ...
# Mahoba *                 1
# BALANGIR                 1
# Chandauli *              1
# Poonch                   1
# Salumbar                 1
# Name: count, Length: 974, dtype: int64

# %%
df['district_clean'] = df['district'].str.lower().str.strip().str.replace(r'[^a-z]', '', regex=True)
df.head()
# Out:
#         date              state      district  pincode  bio_age_5_17  \
# 0 2025-03-01            Haryana  Mahendragarh   123029           280
# 1 2025-03-01              Bihar     Madhepura   852121           144
# 2 2025-03-01  Jammu and Kashmir         Punch   185101           643
# 3 2025-03-01              Bihar       Bhojpur   802158           256
# 4 2025-03-01         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_      state_clean district_clean
# 0          577          haryana   mahendragarh
# 1          369            bihar      madhepura
# 2         1091  jammuandkashmir          punch
# 3          980            bihar        bhojpur
# 4          815        tamilnadu        madurai

# %%
df['district_final'] = df['district_clean'].str.replace(r'\s+', ' ', regex=True)

# %%
df["district_final"].value_counts()
# Out:
# district_final
# pune             11068
# thrissur         10594
# northparganas    10128
# barddhaman       10079
# eastgodavari      9872
#                  ...
# akhera               1
# bandipur             1
#                      1
# poonch               1
# salumbar             1
# Name: count, Length: 911, dtype: int64

# %%
import difflib

# %%
valid_states = [
    "andhrapradesh","arunachalpradesh","assam","bihar","chhattisgarh",
    "goa","gujarat","haryana","himachalpradesh","jharkhand",
    "karnataka","kerala","madhyapradesh","maharashtra","manipur",
    "meghalaya","mizoram","nagaland","odisha","punjab",
    "rajasthan","sikkim","tamilnadu","telangana","tripura",
    "uttarpradesh","uttarakhand","westbengal",
    "jammuandkashmir","delhi"
]

# %%
df['state_final'] = df['state_clean'].apply(
    lambda x: difflib.get_close_matches(x, valid_states, n=1, cutoff=0.75)[0]
    if difflib.get_close_matches(x, valid_states, n=1, cutoff=0.75)
    else x
)

# %%
df['state_final'].value_counts()
# Out:
# state_final
# tamilnadu                            174935
# andhrapradesh                        160232
# uttarpradesh                         147138
# maharashtra                          143609
# karnataka                            135780
# westbengal                           125422
# kerala                                93951
# gujarat                               84630
# odisha                                83217
# bihar                                 78078
# telangana                             77850
# rajasthan                             76698
# madhyapradesh                         66020
# punjab                                46414
# assam                                 44418
# jharkhand                             35054
# chhattisgarh                          30053
# himachalpradesh                       28723
# haryana                               25083
# uttarakhand                           21433
# jammuandkashmir                       18943
# orissa                                12767
# delhi                                  8784
# tripura                                7949
# manipur                                6252
# goa                                    5105
# meghalaya                              4016
# arunachalpradesh                       3957
# nagaland                               3666
# mizoram                                3217
# puducherry                             2535
# sikkim                                 2298
# pondicherry                            2240
# chandigarh                             1576
# andamanandnicobarislands               1190
# ladakh                                  688
# lakshadweep                             525
# andamannicobarislands                   502
# damananddiu                             394
# dadraandnagarhaveli                     310
# damandiu                                252
# dadraandnagarhavelianddamananddiu       214
# dadranagarhaveli                         92
# uttaranchal                               2
# Name: count, dtype: int64

# %%
df['state_final'] = df['state_final'].replace({
    "orissa": "odisha",
    "pondicherry": "puducherry",
    "andamannicobarislands": "andamanandnicobarislands",
    "damananddiu": "dadraandnagarhavelianddamananddiu",
    "damandiu": "dadraandnagarhavelianddamananddiu",
    "dadraandnagarhaveli": "dadraandnagarhavelianddamananddiu",
    "dadranagarhaveli": "dadraandnagarhavelianddamananddiu"
})
df['state_final'].value_counts()
# Out:
# state_final
# tamilnadu                            174935
# andhrapradesh                        160232
# uttarpradesh                         147138
# maharashtra                          143609
# karnataka                            135780
# westbengal                           125422
# odisha                                95984
# kerala                                93951
# gujarat                               84630
# bihar                                 78078
# telangana                             77850
# rajasthan                             76698
# madhyapradesh                         66020
# punjab                                46414
# assam                                 44418
# jharkhand                             35054
# chhattisgarh                          30053
# himachalpradesh                       28723
# haryana                               25083
# uttarakhand                           21433
# jammuandkashmir                       18943
# delhi                                  8784
# tripura                                7949
# manipur                                6252
# goa                                    5105
# puducherry                             4775
# meghalaya                              4016
# arunachalpradesh                       3957
# nagaland                               3666
# mizoram                                3217
# sikkim                                 2298
# andamanandnicobarislands               1692
# chandigarh                             1576
# dadraandnagarhavelianddamananddiu      1262
# ladakh                                  688
# lakshadweep                             525
# uttaranchal                               2
# Name: count, dtype: int64

# %%
df = df[df['state_final'].str.len() > 0]

# %%
df.head()
# Out:
#         date              state      district  pincode  bio_age_5_17  \
# 0 2025-03-01            Haryana  Mahendragarh   123029           280
# 1 2025-03-01              Bihar     Madhepura   852121           144
# 2 2025-03-01  Jammu and Kashmir         Punch   185101           643
# 3 2025-03-01              Bihar       Bhojpur   802158           256
# 4 2025-03-01         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_      state_clean district_clean district_final      state_final
# 0          577          haryana   mahendragarh   mahendragarh          haryana
# 1          369            bihar      madhepura      madhepura            bihar
# 2         1091  jammuandkashmir          punch          punch  jammuandkashmir
# 3          980            bihar        bhojpur        bhojpur            bihar
# 4          815        tamilnadu        madurai        madurai        tamilnadu

# %%
df = df[['date', 'state_final',	'district_final',	'pincode','bio_age_5_17','bio_age_17_']]
df.head()
# Out:
#         date      state_final district_final  pincode  bio_age_5_17  \
# 0 2025-03-01          haryana   mahendragarh   123029           280
# 1 2025-03-01            bihar      madhepura   852121           144
# 2 2025-03-01  jammuandkashmir          punch   185101           643
# 3 2025-03-01            bihar        bhojpur   802158           256
# 4 2025-03-01        tamilnadu        madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
df["total_biometric"]=df["bio_age_5_17"]+df["bio_age_17_"]

# %%
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month   
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#         date      state_final district_final  pincode  bio_age_5_17  \
# 0 2025-03-01          haryana   mahendragarh   123029           280
# 1 2025-03-01            bihar      madhepura   852121           144
# 2 2025-03-01  jammuandkashmir          punch   185101           643
# 3 2025-03-01            bihar        bhojpur   802158           256
# 4 2025-03-01        tamilnadu        madurai   625514           271
#
#    bio_age_17_  total_biometric  day  month  year
# 0          577              857    1      3  2025
# 1          369              513    1      3  2025
# 2         1091             1734    1      3  2025
# 3          980             1236    1      3  2025
# 4          815             1086    1      3  2025

# %%
df.groupby('pincode')['state_final'].nunique().max()
# Out:
# np.int64(2)

# %%
bad_pincodes = df.groupby('pincode')['state_final'].nunique()
bad_pincodes = bad_pincodes[bad_pincodes > 1]
bad_pincodes
# Out:
# pincode
# 140308    2
# 140603    2
# 140901    2
# 160003    2
# 160014    2
#          ..
# 756084    2
# 781131    2
# 783123    2
# 783134    2
# 798628    2
# Name: state_final, Length: 702, dtype: int64

# %%
df[df['pincode'].isin(bad_pincodes.index)][['pincode', 'state_final']].sort_values('pincode')
# Out:
#          pincode state_final
# 1765200   140308      punjab
# 284608    140308      punjab
# 1051399   140308      punjab
# 1078108   140308      punjab
# 1200490   140308      punjab
# ...          ...         ...
# 1386920   798628    nagaland
# 1346615   798628    nagaland
# 153264    798628    nagaland
# 540257    798628    nagaland
# 530067    798628    nagaland
#
# [124922 rows x 2 columns]

# %%
for pin in bad_pincodes.index:
    correct_state = (df[df['pincode'] == pin]['state_final'].value_counts().idxmax())
    df.loc[df['pincode'] == pin, 'state_final'] = correct_state

# %%
df.groupby('pincode')['state_final'].nunique().max()  # fixed.
# Out:
# np.int64(1)

# %%
df.head()  # data cleaning complete.
# Out:
#         date      state_final district_final  pincode  bio_age_5_17  \
# 0 2025-03-01          haryana   mahendragarh   123029           280
# 1 2025-03-01            bihar      madhepura   852121           144
# 2 2025-03-01  jammuandkashmir          punch   185101           643
# 3 2025-03-01            bihar        bhojpur   802158           256
# 4 2025-03-01        tamilnadu        madurai   625514           271
#
#    bio_age_17_  total_biometric  day  month  year
# 0          577              857    1      3  2025
# 1          369              513    1      3  2025
# 2         1091             1734    1      3  2025
# 3          980             1236    1      3  2025
# 4          815             1086    1      3  2025

# %%
df['total_biometric'].describe()
# Out:
# count    1.766212e+06
# mean     3.864828e+01
# std      1.664470e+02
# min      0.000000e+00
# 25%      3.000000e+00
# 50%      8.000000e+00
# 75%      2.200000e+01
# max      1.338100e+04
# Name: total_biometric, dtype: float64

# %%
sns.set_style("whitegrid")

# %%
plt.Figure(figsize=(9,6))
sns.kdeplot(df["total_biometric"],fill=True,color="purple")
plt.title("Density plot of Total Biometric")
plt.show()

# %%
#age group wise distribution
df[["bio_age_5_17","bio_age_17_"]].describe()
# Out:
#        bio_age_5_17   bio_age_17_
# count  1.766212e+06  1.766212e+06
# mean   1.894260e+01  1.970568e+01
# std    8.581746e+01  9.030576e+01
# min    0.000000e+00  0.000000e+00
# 25%    1.000000e+00  1.000000e+00
# 50%    4.000000e+00  4.000000e+00
# 75%    1.100000e+01  1.000000e+01
# max    8.002000e+03  7.625000e+03

# %%
sns.barplot(df[["bio_age_5_17","bio_age_17_"]], palette='Purples_r')
plt.title('Average Biometric by Age Group')
plt.xlabel('Age Groups')
plt.ylabel('Average Biometric')
plt.show()

# %%
# monthly trend
monthly_biometric = df.groupby(['month'])['total_biometric'].sum().reset_index()
monthly_biometric = pd.DataFrame(monthly_biometric)
monthly_biometric.sort_values('total_biometric', ascending=False)
# Out:
#    month  total_biometric
# 4      7          9792552
# 1      4          8641679
# 0      3          8322222
# 8     12          8207196
# 3      6          7899289
# 2      5          7879956
# 7     11          6770804
# 5      9          6513507
# 6     10          4233854

# %%
sns.barplot(
    data=monthly_biometric.sort_values(by='total_biometric', ascending=False),
    x='month',
    y='total_biometric',
    hue='month',
    palette='Purples_r',
    legend=False
)
plt.title('Monthly Aadhaar Updates')
plt.xlabel('Month')
plt.ylabel('Total Updates')
plt.show()

# %%
# weekly trends
df['day_of_week'] = df['date'].dt.day_name()
weekly_biometric = df.groupby('day_of_week')['total_biometric'].sum().reset_index()
weekly_biometric = pd.DataFrame(weekly_biometric)
weekly_biometric.sort_values('total_biometric', ascending=False)
# Out:
#   day_of_week  total_biometric
# 5     Tuesday         22836504
# 2    Saturday         12254818
# 4    Thursday         11803050
# 3      Sunday         10014634
# 0      Friday          4145169
# 1      Monday          3868043
# 6   Wednesday          3338841

# %%
sns.barplot(
    data=weekly_biometric.sort_values(by='total_biometric', ascending=False),
    y='day_of_week',
    x='total_biometric',
    hue='day_of_week',
    palette='Purples_r',
    legend=False
)
# Out:
# <Axes: xlabel='total_biometric', ylabel='day_of_week'>

# %%
state_enrol = df.groupby('state_final')['total_biometric'].sum().reset_index()
state_enrol = pd.DataFrame(state_enrol)
state_enrol = state_enrol.sort_values(by='total_biometric', ascending=False)
state_enrol
# Out:
#                           state_final  total_biometric
# 34                       uttarpradesh          9370869
# 20                        maharashtra          9020712
# 19                      madhyapradesh          5819736
# 4                               bihar          4778966
# 30                          tamilnadu          4568414
# 28                          rajasthan          3927997
# 1                       andhrapradesh          3329020
# 10                            gujarat          3142845
# 15                          karnataka          2602087
# 6                        chhattisgarh          2559111
# 35                         westbengal          2482162
# 25                             odisha          2423769
# 14                          jharkhand          1995940
# 31                          telangana          1956578
# 27                             punjab          1731592
# 11                            haryana          1600264
# 16                             kerala          1585641
# 8                               delhi          1281944
# 3                               assam           945193
# 13                    jammuandkashmir           773827
# 33                        uttarakhand           737010
# 12                    himachalpradesh           385264
# 32                            tripura           285324
# 21                            manipur           275899
# 23                            mizoram           119160
# 24                           nagaland           108272
# 22                          meghalaya            86531
# 26                         puducherry            75844
# 2                    arunachalpradesh            70059
# 9                                 goa            66554
# 5                          chandigarh            59805
# 7   dadraandnagarhavelianddamananddiu            43935
# 29                             sikkim            22577
# 0            andamanandnicobarislands            19994
# 18                        lakshadweep             4745
# 17                             ladakh             3419

# %%
plt.figure(figsize=(10,8))
sns.barplot(
    data=state_enrol,
    y='state_final',
    x='total_biometric',
    hue='state_final',
    palette='Purples_r',
    legend=False
)
plt.xlabel('Total Enrolments')
plt.ylabel('States')
plt.title('Aadhaar Enrolments by State')
plt.show()

# %%
state_age = (
    df.groupby('state_final')[['bio_age_5_17','bio_age_17_']]
    .sum()
    .reset_index()
)

state_age_melted = state_age.melt(
    id_vars='state_final',
    value_vars=['bio_age_5_17','bio_age_17_'],
    var_name='Age Group',
    value_name='Updates'
)

plt.figure(figsize=(10,8))
sns.barplot(
    data=state_age_melted,
    x='state_final',
    y='Updates',
    hue='Age Group',
    palette="Purples"
)
plt.title("State-wise Biometric Updates by Age Group")
plt.xlabel("State")
plt.ylabel("Number of Updates")
plt.xticks(rotation=90)
plt.show()

# %%
top_districts = (
    df.groupby('district_final')['total_biometric']
    .sum()
    .reset_index()
    .sort_values(by='total_biometric', ascending=False)
    .head(10)
)

plt.figure(figsize=(8,6))
sns.barplot(
    data=top_districts,
    x='total_biometric',
    y='district_final',
    hue='district_final',
    palette="Purples_r",
    legend=False
)
plt.title("Top 10 Districts by Aadhaar Biometric Updates")
plt.xlabel("Total Updates")
plt.ylabel("District")
plt.show()

# %%
heatmap_data = (
    df.groupby('state_final')[['bio_age_5_17','bio_age_17_']]
    .sum()
)

plt.figure(figsize=(10,8))
sns.heatmap(
    heatmap_data,
    annot=True,
    fmt='d',
    cmap='Purples'
)
plt.title("Heatmap of Biometric Updates by State and Age Group")
plt.xlabel("Age Group")
plt.ylabel("State")
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

date_trend = (
    df.groupby('date')['total_biometric']
    .sum()
    .reset_index()
)

plt.figure(figsize=(8,5))
sns.lineplot(
    data=date_trend,
    x='date',
    y='total_biometric',
    color='Purple'
)
plt.title("Trend of Aadhaar Biometric Updates Over Time")
plt.xlabel("Date")
plt.ylabel("Total Updates")
plt.show()
