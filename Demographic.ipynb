# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
demo1 = pd.read_csv('api_data_aadhar_demographic_0_500000.csv')
demo2 = pd.read_csv('api_data_aadhar_demographic_500000_1000000.csv')
demo3 = pd.read_csv('api_data_aadhar_demographic_1000000_1500000.csv')
demo4 = pd.read_csv('api_data_aadhar_demographic_1500000_2000000.csv')
demo5 = pd.read_csv('api_data_aadhar_demographic_2000000_2071700.csv')

# %%
demo_combined = pd.concat([demo1,demo2,demo3,demo4,demo5], ignore_index = True)

# %%
df = demo_combined.copy()

# %%
df.shape
# Out:
# (2071700, 6)

# %%
df.head(4)
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314

# %%
df.isnull().sum()
# Out:
# date             0
# state            0
# district         0
# pincode          0
# demo_age_5_17    0
# demo_age_17_     0
# dtype: int64

# %%
df.describe()
# Out:
#             pincode  demo_age_5_17  demo_age_17_
# count  2.071700e+06   2.071700e+06  2.071700e+06
# mean   5.278318e+05   2.347552e+00  2.144701e+01
# std    1.972933e+05   1.490355e+01  1.252498e+02
# min    1.000000e+05   0.000000e+00  0.000000e+00
# 25%    3.964690e+05   0.000000e+00  2.000000e+00
# 50%    5.243220e+05   1.000000e+00  6.000000e+00
# 75%    6.955070e+05   2.000000e+00  1.500000e+01
# max    8.554560e+05   2.690000e+03  1.616600e+04

# %%
df.dtypes
# Out:
# date             object
# state            object
# district         object
# pincode           int64
# demo_age_5_17     int64
# demo_age_17_      int64
# dtype: object

# %%
df.rename(columns = {
    'demo_age_17_' : 'age_17_plus_count',
    'demo_age_5_17' : 'age_5_17_count'
}, inplace = True)

# %%
df.columns.tolist()
# Out:
# ['date', 'state', 'district', 'pincode', 'age_5_17_count', 'age_17_plus_count']

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst = True, errors = 'coerce')

# %%
df['date'].isna().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# df['date'].min(), df['date'].max()
# Out:
# date                 datetime64[ns]
# state                        object
# district                     object
# pincode                       int64
# age_5_17_count                int64
# age_17_plus_count             int64
# dtype: object

# %%
df['pincode'] = df['pincode'].astype(str)

# %%
df['state'] = df['state'].str.strip().str.lower()
df['district'] = df['district'].str.strip().str.lower()

# %%
df.head(3)
# Out:
#         date           state   district pincode  age_5_17_count  \
# 0 2025-03-01   uttar pradesh  gorakhpur  273213              49
# 1 2025-03-01  andhra pradesh   chittoor  517132              22
# 2 2025-03-01         gujarat     rajkot  360006              65
#
#    age_17_plus_count
# 0                529
# 1                375
# 2                765

# %%
df.duplicated().sum()
# Out:
# np.int64(473688)

# %%
df[df.duplicated()].head()
# Out:
#              date        state           district pincode  age_5_17_count  \
# 182369 2025-12-06       odisha             jajpur  755020               0
# 219406 2025-11-10  west bengal  south 24 parganas  743368               0
# 227394 2025-10-26   tamil nadu        krishnagiri  635207               6
# 227395 2025-10-26   tamil nadu        krishnagiri  635306               6
# 227396 2025-10-26   tamil nadu        krishnagiri  635307               5
#
#         age_17_plus_count
# 182369                  1
# 219406                  1
# 227394                 17
# 227395                  3
# 227396                 17

# %%
df = df.drop_duplicates().reset_index(drop = True)

# %%
df['state'].unique()
# Out:
# array(['uttar pradesh', 'andhra pradesh', 'gujarat', 'rajasthan',
#        'karnataka', 'west bengal', 'telangana', 'odisha', 'maharashtra',
#        'kerala', 'bihar', 'tamil nadu', 'madhya pradesh', 'assam',
#        'tripura', 'arunachal pradesh', 'punjab', 'jharkhand', 'delhi',
#        'chandigarh', 'chhattisgarh', 'jammu and kashmir', 'mizoram',
#        'nagaland', 'himachal pradesh', 'goa', 'haryana', 'meghalaya',
#        'uttarakhand', 'manipur', 'daman and diu', 'puducherry', 'sikkim',
#        'ladakh', 'dadra and nagar haveli and daman and diu',
#        'dadra and nagar haveli', 'orissa', 'pondicherry',
#        'andaman & nicobar islands', 'andaman and nicobar islands',
#        'daman & diu', 'west  bengal', 'jammu & kashmir', 'lakshadweep',
#        'dadra & nagar haveli', 'westbengal', 'west bangal', 'chhatisgarh',
#        'west bengli', 'darbhanga', 'puttenahalli', 'balanagar',
#        'uttaranchal', '100000', 'jaipur', 'madanapalle', 'nagpur',
#        'raja annamalai puram'], dtype=object)

# %%
df['state_clean'] = df['state'].str.lower().str.strip().str.replace(r'[^a-z]', '', regex=True)

# %%
valid_states = [
    "andhrapradesh","arunachalpradesh","assam","bihar","chhattisgarh",
    "goa","gujarat","haryana","himachalpradesh","jharkhand",
    "karnataka","kerala","madhyapradesh","maharashtra","manipur",
    "meghalaya","mizoram","nagaland","odisha","punjab",
    "rajasthan","sikkim","tamilnadu","telangana","tripura",
    "uttarpradesh","uttarakhand","westbengal",
    "jammuandkashmir","delhi"
]

from rapidfuzz import process
unique_state = df['state_clean'].unique()

mapping = {
    messy: process.extractOne(messy, valid_states, score_cutoff = 75)[0]
    if process.extractOne(messy, valid_states, score_cutoff = 75) else messy
    for messy in unique_state
    }

df['state_final'] = df['state_clean'].map(mapping)

# %%
df['state_final'].unique()
# Out:
# array(['uttarpradesh', 'andhrapradesh', 'gujarat', 'rajasthan',
#        'karnataka', 'westbengal', 'telangana', 'odisha', 'maharashtra',
#        'kerala', 'bihar', 'tamilnadu', 'madhyapradesh', 'assam',
#        'tripura', 'arunachalpradesh', 'punjab', 'jharkhand', 'delhi',
#        'chandigarh', 'chhattisgarh', 'jammuandkashmir', 'mizoram',
#        'nagaland', 'himachalpradesh', 'goa', 'haryana', 'meghalaya',
#        'uttarakhand', 'manipur', 'damananddiu', 'puducherry', 'sikkim',
#        'ladakh', 'dadraandnagarhavelianddamananddiu',
#        'dadraandnagarhaveli', 'orissa', 'pondicherry',
#        'andamannicobarislands', 'andamanandnicobarislands', 'damandiu',
#        'lakshadweep', 'dadranagarhaveli', 'darbhanga', 'puttenahalli',
#        'balanagar', 'uttaranchal', '', 'madanapalle', 'nagpur',
#        'rajaannamalaipuram'], dtype=object)

# %%
df['state_final'] = df['state_final'].replace({
    "orissa": "odisha",
    "pondicherry": "puducherry",
    "andamannicobarislands": "andamanandnicobarislands",
    "damananddiu": "dadraandnagarhavelianddamananddiu",
    "damandiu": "dadraandnagarhavelianddamananddiu",
    "dadraandnagarhaveli": "dadraandnagarhavelianddamananddiu",
    "dadranagarhaveli": "dadraandnagarhavelianddamananddiu"
})

# %%
df['state_final'].value_counts()
# Out:
# state_final
# andhrapradesh                        154789
# tamilnadu                            153333
# uttarpradesh                         132366
# maharashtra                          126303
# westbengal                           125013
# karnataka                            120403
# odisha                                82463
# kerala                                82186
# gujarat                               75161
# bihar                                 74536
# telangana                             70098
# rajasthan                             68455
# madhyapradesh                         60157
# assam                                 47408
# punjab                                38097
# jharkhand                             31225
# chhattisgarh                          27288
# haryana                               22341
# himachalpradesh                       21940
# uttarakhand                           17710
# jammuandkashmir                       16015
# delhi                                  8066
# tripura                                6968
# manipur                                5745
# goa                                    4609
# meghalaya                              4180
# puducherry                             3810
# arunachalpradesh                       3608
# nagaland                               3109
# mizoram                                3010
# sikkim                                 2452
# chandigarh                             1536
# andamanandnicobarislands               1289
# dadraandnagarhavelianddamananddiu      1250
# ladakh                                  672
# lakshadweep                             410
# uttaranchal                               3
#                                           2
# puttenahalli                              1
# darbhanga                                 1
# balanagar                                 1
# madanapalle                               1
# nagpur                                    1
# rajaannamalaipuram                        1
# Name: count, dtype: int64

# %%
df = df[df['state_final'].map(df['state_final'].value_counts())>1]

# %%
df = df[df['state_final'].notna()]
df = df[df['state_final'] != '']
df = df[df['state_final'].str.len() > 0]

# %%
df.head()
# Out:
#         date           state    district pincode  age_5_17_count  \
# 0 2025-03-01   uttar pradesh   gorakhpur  273213              49
# 1 2025-03-01  andhra pradesh    chittoor  517132              22
# 2 2025-03-01         gujarat      rajkot  360006              65
# 3 2025-03-01  andhra pradesh  srikakulam  532484              24
# 4 2025-03-01       rajasthan     udaipur  313801              45
#
#    age_17_plus_count    state_clean    state_final
# 0                529   uttarpradesh   uttarpradesh
# 1                375  andhrapradesh  andhrapradesh
# 2                765        gujarat        gujarat
# 3                314  andhrapradesh  andhrapradesh
# 4                785      rajasthan      rajasthan

# %%
df['total_updates'] = df['age_5_17_count'] + df['age_17_plus_count']
# Total number of people who updated their demograhic details.

# %%
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df.groupby('pincode')['state_final'].nunique().max()
# Out:
# np.int64(2)

# %%
bad_pincodes = df.groupby('pincode')['state_final'].nunique()
bad_pincodes = bad_pincodes[bad_pincodes > 1]
bad_pincodes
# Out:
# pincode
# 140603    2
# 140901    2
# 160003    2
# 160014    2
# 160055    2
#          ..
# 756084    2
# 781129    2
# 781131    2
# 783123    2
# 783134    2
# Name: state_final, Length: 698, dtype: int64

# %%
df[df['pincode'].isin(bad_pincodes.index)][['pincode', 'state_final']].sort_values('pincode')
# Out:
#         pincode state_final
# 908807   140603      punjab
# 415178   140603      punjab
# 885377   140603      punjab
# 380325   140603      punjab
# 700202   140603      punjab
# ...         ...         ...
# 1145131  783134       assam
# 104862   783134   meghalaya
# 646758   783134       assam
# 1143352  783134       assam
# 385526   783134   meghalaya
#
# [110743 rows x 2 columns]

# %%
for pin in bad_pincodes.index: 
    correct_state = (df[df['pincode'] == pin]['state_final'].value_counts().idxmax()) 
    df.loc[df['pincode'] == pin, 'state_final'] = correct_state

# %%
df.head()
# data cleaning done
# Out:
#         date           state    district pincode  age_5_17_count  \
# 0 2025-03-01   uttar pradesh   gorakhpur  273213              49
# 1 2025-03-01  andhra pradesh    chittoor  517132              22
# 2 2025-03-01         gujarat      rajkot  360006              65
# 3 2025-03-01  andhra pradesh  srikakulam  532484              24
# 4 2025-03-01       rajasthan     udaipur  313801              45
#
#    age_17_plus_count    state_clean    state_final  total_updates  day  month  \
# 0                529   uttarpradesh   uttarpradesh            578    1      3
# 1                375  andhrapradesh  andhrapradesh            397    1      3
# 2                765        gujarat        gujarat            830    1      3
# 3                314  andhrapradesh  andhrapradesh            338    1      3
# 4                785      rajasthan      rajasthan            830    1      3
#
#    year
# 0  2025
# 1  2025
# 2  2025
# 3  2025
# 4  2025

# %%
df['district'].unique()
# Out:
# array(['gorakhpur', 'chittoor', 'rajkot', 'srikakulam', 'udaipur',
#        'sikar', 'tumakuru', 'kurnool', 'paschim medinipur', 'ghazipur',
#        'patan', 'mulugu', 'ganganagar', 'nayagarh', 'nashik',
#        'shivamogga', 'thrissur', 'hassan', 'patna', 'belgaum',
#        'kancheepuram', 'jabalpur', 'chennai', 'tinsukia', 'jamui', 'gaya',
#        'bengaluru', 'tiruppur', 'jalgaon', 'dhalai', 'nabarangapur',
#        'chittorgarh', 'darbhanga', 'purnia', 'muzaffarnagar', 'jaipur',
#        'churu', 'bharatpur', 'jamnagar', 'howrah', 'ahmedabad',
#        'west kameng', 'jalor', 'belagavi', 'bahraich', 'nagapattinam',
#        'sheikhpura', 'amritsar', 'mysore', 'alluri sitharama raju',
#        'sitamarhi', 'khunti', 'saharanpur', 'kanyakumari', 'prakasam',
#        'ananthapuramu', 'hooghly', 'central delhi', 'deoria', 'giridih',
#        'koraput', 'shahjahanpur', 'chhotaudepur', 'jalandhar', 'kannauj',
#        'visakhapatnam', 'jodhpur', 'karimnagar', 'amethi', 'hyderabad',
#        'salem', 'cuddalore', 'sabarkantha', 'kolar', 'nagpur',
#        'porbandar', 'chandigarh', 'paschim bardhaman', 'devbhumi dwarka',
#        'nalgonda', 'tawang', 'muzaffarpur', 'ganjam', 'kawardha',
#        'east godavari', 'dhanbad', 'gandhinagar', 'puruliya',
#        'siddharthnagar', 'bara banki', 'saran', 'hardoi',
#        'south 24 parganas', 'ambedkar nagar', 'tiruchirappalli', 'indore',
#        'tiruvannamalai', 'kasaragod', 'mumbai', 'mysuru', 'gopalganj',
#        'surendra nagar', 'annamayya', 'dindigul', 'narayanpet', 'tenkasi',
#        'mahesana', 'north east delhi', 'firozpur', 'araria', 'auraiya',
#        'krishnagiri', 'betul', 'satna', 'sangareddy', 'dahod',
#        'prayagraj', 'katihar', 'anakapalli', 'pratapgarh', 'kallakurichi',
#        'tikamgarh', 'bhojpur', 'jammu', 'khargone', 'aizawl', 'dholpur',
#        'kheda', 'madhubani', 'nawada', 'solapur', 'mayurbhanj', 'rewa',
#        'sambalpur', 'tiruvallur', 'bokaro', 'dakshina kannada',
#        'purba medinipur', 'north 24 parganas', 'peren', 'kangra',
#        'kendrapara', 'palghar', 'erode', 'malappuram', 'rajouri',
#        'north goa', 'balrampur', 'surat', 'south delhi', 'khammam',
#        'kendujhar', 'ludhiana', 'coimbatore', 'rae bareli', 'amravati',
#        'krishna', 'bhadrak', 'parbhani', 'valsad', 'azamgarh',
#        'chhatarpur', 'amroha', 'jalna', 'parvathipuram manyam', 'sirmaur',
#        'west godavari', 'k.v. rangareddy', 'vijayapura', 'unakoti',
#        'virudhunagar', 'vadodara', 'sonipat', 'sultanpur', 'nadia',
#        'warangal', 'udupi', 'baramula', 'kalaburagi', 'nandyal',
#        'ernakulam', 'south west delhi', 'murshidabad',
#        'east jaintia hills', 'mandya', 'bijapur', 'gonda', 'kannur',
#        'mainpuri', 'medchal-malkajgiri', 'jajpur', 'moradabad',
#        'namakkal', 'davangere', 'ganderbal', 'alappuzha', 'arvalli',
#        'rohtak', 'samastipur', 'medak', 'ahmadnagar', 'ratnagiri',
#        'chamrajanagar', 'buxar', 'mumbai suburban', 'nagarkurnool',
#        'charaideo', 'peddapalli', 'west champaran', 'cuddapah',
#        'khagaria', 'pune', 'chhindwara', 'east champaran', 'udalguri',
#        'nalbari', 'varanasi', 'chitradurga', 'adilabad', 'karimganj',
#        'nagaon', 'kolkata', 'gurgaon', 'east singhbhum', 'jajapur',
#        'agar malwa', 'gwalior', 'bijnor', 'kaithal', 'vellore', 'ballari',
#        'bankura', 'gulbarga', 'ramanathapuram', 'chumukedima',
#        'firozabad', 'barddhaman', 'farrukhabad', 'hisar',
#        'sri muktsar sahib', 'basti', 'baleswar', 'chikkaballapur',
#        'uttara kannada', 'botad', 'jalpaiguri', 'vizianagaram',
#        'dhenkanal', 'jaunpur', 'umaria', 'warangal rural', 'panchkula',
#        'kakinada', 'pithoragarh', 'pathanamthitta', 'palnadu',
#        'maharajganj', 'latehar', 'srinagar', 'badgam', 'buldhana',
#        'bikaner', 'moga', 'kaushambi', 'alwar', 'satara', 'damoh', 'puri',
#        'chamba', 'khorda', 'morbi', 'tirunelveli', 'bundi', 'kathua',
#        'ananthapur', 'chikkamagaluru', 'maihar', 'sitapur', 'aligarh',
#        'bagalkot', 'lakhimpur', 'kodagu', 'rajsamand', 'villupuram',
#        'karbi anglong', 'gajapati', 'shajapur', 'anantnag', 'karnal',
#        'guna', 'kheri', 'kachchh', 'purba bardhaman', 'angul',
#        'chandrapur', 'koppal', 'west garo hills', 'vikarabad', 'mau',
#        'churachandpur', 'dehradun', 'saharsa', 'sonbhadra', 'jhalawar',
#        'hoshangabad', 'baloda bazar', 'pulwama', 'tumkur', 'nuapada',
#        'aurangabad', 'rupnagar', 'sehore', 'bulandshahr', 'hanumakonda',
#        'narsinghpur', 'rohtas', 'fatehpur', 'jogulamba gadwal', 'n. t. r',
#        'osmanabad', 'daman', 'ajmer', 'dharmapuri', 'garhwa', 'pali',
#        'goalpara', 'ayodhya', 'anand', 'hailakandi', 'kozhikode', 'mandi',
#        'mandsaur', 'raichur', 'eluru', 'kasganj', 'kabeerdham',
#        'tehri garhwal', 'south goa', 'faizabad', 'gadag',
#        'dr. b. r. ambedkar konaseema', 'baleshwar', 'dausa', 'siddipet',
#        'nagaur', 'ariyalur', 'ballia', 'kanpur nagar', 'neemuch',
#        'guntur', 'yavatmal', 'niwari', 'bharuch', 'uttar dinajpur',
#        'munger', 'east nimar', 'latur', 'ambala', 'bathinda', 'ramban',
#        'lucknow', 'nandurbar', 'theni', 'bhadradri kothagudem',
#        'nainital', 'bhopal', 'tirupattur', 'mahabubnagar', 'barpeta',
#        'cuttack', 'jashpur', 'gir somnath', 'kolhapur', 'datia',
#        'jhunjhunun', 'junagadh', 'seoni', 'agra', 'thane', 'rewari',
#        'bilaspur', 'raigarh', 'thiruvarur', 'jhajjar', 'sant kabir nagar',
#        'jagitial', 'anantapur', 'karur', 'arwal', 'shrawasti', 'golaghat',
#        'ujjain', 'sirohi', 'samba', 'nizamabad', 'bhilwara', 'darjeeling',
#        'marigaon', 'rajgarh', 'lohardaga', 'akola', 'pudukkottai',
#        'siwan', 'patiala', 'katni', 'sivaganga', 'budgam', 'kamrup metro',
#        'kapurthala', 'beed', 'banaskantha', 'sonitpur', 'tonk', 'bhadohi',
#        'dibrugarh', 'sangrur', 'thiruvananthapuram', 'narmadapuram',
#        'jorhat', 'hanumangarh', 'barwani', 'birbhum', 'dhule', 'gadag *',
#        'malda', 'kanker', 'yadadri.', 'ghaziabad', 'cachar', 'lalitpur',
#        'bastar', 'boudh', 'bhiwani', 'mandla', 'ri bhoi', 'simdega',
#        'janjgir-champa', 'jagatsinghapur', 'baksa', 'dohad',
#        'sas nagar (mohali)', 'dharwad', 'meerut', 'mathura', 'shivpuri',
#        'gumla', 'uttarkashi', 'banswara', 'bapatla', 'kanniyakumari',
#        'burhanpur', 'allahabad', 'bellary', 'fazilka', 'kaimur (bhabua)',
#        'kamareddy', 'etah', 'etawah', 'vaishali', 'gautam buddha nagar',
#        'haridwar', 'dhar', 'balangir', 'hathras', 'sibsagar',
#        'rangareddi', 'nanded', 'bongaigaon', 'bandipore', 'chamoli',
#        'imphal east', 'jind', 'kota', 'udham singh nagar',
#        'north west delhi', 'champawat', 'shahdol', 'una', 'sirsa',
#        'mewat', 'suryapet', 'faridabad', 'east delhi', 'gurdaspur',
#        'mahasamund', 'baran', 'sri sathya sai', 'surguja', 'raipur',
#        'balaghat', 'yamuna nagar', 'madurai', 'shahdara', 'rampur',
#        'kupwara', 'dindori', 'kulgam', 'gadchiroli', 'north delhi',
#        'mumbai city', 'haveri', 'west delhi', 'barmer', 'balod',
#        'ferozepur', 'sagar', 'hoshiarpur', 'koriya', 'bareilly', 'punch',
#        'raisen', 'mahendragarh', 'serchhip', 'pauri garhwal',
#        'kurukshetra', 'anuppur', 'fatehabad', 'durg', 'korba', 'vidisha',
#        'dewas', 'ratlam', 'kolasib', 'ramanagar', 'doda',
#        'sri potti sriramulu nellore', 'ashok nagar', 'mungeli',
#        'rajnandgaon', 'viluppuram', 'sidhi', 'bidar', 'jhansi',
#        'bhavnagar', 'jhabua', 'puducherry', 'charkhi dadri', 'tirupati',
#        'harda', 'y. s. r', 'bhind', 'tarn taran', 'yadgir',
#        'bangalore rural', 'vijayanagara', 'raigad', 'kokrajhar', 'shimla',
#        'pilibhit', 'west sikkim', 'alirajpur', 'palamu', 'karauli',
#        'deoghar', 'nellore', 'sindhudurg', 'chickmagalur', 'hamirpur',
#        'jharsuguda', 'begusarai', 'washim', 'kargil', 'dumka',
#        'pathankot', 'kalahandi', 'shamli', 'mahoba', 'panna', 'bageshwar',
#        'dhamtari', 'navsari', 'palakkad', 'sundergarh', 'sambhal',
#        'wayanad', 'sahebganj', 'sant ravidas nagar', 'nalanda',
#        'rayagada', 'dhubri', 'west khasi hills', 'almora', 'sangli',
#        'solan', 'rudraprayag', 'bangalore', 'supaul', 'khowai', 'darrang',
#        'jangoan', 'kanpur dehat', 'gariyaband', 'jehanabad', 'singrauli',
#        'kodarma', 'thanjavur', 'mahbubnagar', 'hazaribagh', 'east',
#        'debagarh', 'panchmahals', 'west tripura', 'amreli',
#        'west singhbhum', 'madhepura', 'baghpat', 'sonapur', 'dhemaji',
#        'seraikela-kharsawan', 'zunheboto', 'bhagalpur', 'kushinagar',
#        'kalimpong', 'jhargram', 'lakhisarai', 'tapi', 'gondiya',
#        'east khasi hills', 'chhatrapati sambhajinagar', 'sawai madhopur',
#        'jaisalmer', 'ranchi', 'mancherial', 'mirzapur', 'cooch behar',
#        'senapati', 'karaikal', 'bemetara', 'budaun', 'hojai', 'godda',
#        'kottayam', 'uttar bastar kanker', 'thoothukkudi', 'dimapur',
#        'unnao', 'kondagaon', 'faridkot', 'tamenglong', 'bargarh',
#        'khandwa', 'hasan', 'chatra', 'jalaun', 'dakshin dinajpur',
#        'mahisagar', 'kollam', 'south tripura', 'shimoga', 'the dangs',
#        'nirmal', 'hapur', 'malkangiri', 'thoubal', 'lohit',
#        'gaurela-pendra-marwahi', 'komaram bheem', 'west nimar',
#        'north tripura', 'banka', 'lunglei', 'dungarpur', 'wanaparthy',
#        'bishnupur', 'kandhamal', 'mamit', 'south salmara mankachar',
#        'morena', 'north cachar hills', 'medchal?malkajgiri', 'kra daadi',
#        'surajpur', 'mahabubabad', 'mansa', 'udhampur', 'narsimhapur',
#        'saiha', 'sukma', 'jiribam', 'ranipet', 'chandauli', 'panipat',
#        'koderma', 'the nilgiris', 'idukki', 'kamrup',
#        'jayashankar bhupalpally', 'warangal urban', 'sheohar',
#        'upper siang', 'mauganj', 'diu', 'malerkotla', 'kiphire',
#        'mohla-manpur-ambagarh chouki', 'palwal',
#        'khairagarh chhuikhadan gandai', 'kishtwar', 'wardha',
#        'kishanganj', 'sheopur', 'narmada', 'chamarajanagar',
#        'chikmagalur', 'davanagere', 'leh', 'harda *', 'pandhurna',
#        'ahmed nagar', 'bhandara', 'bid', 'buldana', 'dharashiv', 'gondia',
#        'gondiya *', 'hingoli', 'purba champaran', 'purnea', 'sheikpura',
#        'dakshin bastar dantewada', 'dantewada',
#        'manendragarh–chirmiri–bharatpur', 'sakti',
#        'dadra and nagar haveli', 'najafgarh', 'new delhi', 'north east',
#        'south east delhi', 'ahmadabad', 'banas kantha', 'panch mahals',
#        'sabar kantha', 'surendranagar', 'yamunanagar', 'kinnaur', 'kullu',
#        'garhwa *', 'hazaribag', 'jamtara', 'pakaur', 'pakur', 'palamau',
#        'purbi singhbhum', 'ramgarh', 'mumbai( sub urban )', 'chandel',
#        'imphal west', 'north garo hills', 'south garo hills',
#        'south west garo hills', 'west jaintia hills', 'champhai',
#        'mammit', 'kohima', 'longleng', 'meluri', 'mokokchung', 'mon',
#        'tseminyu', 'anugul', 'baudh', 'jagatsinghpur', 'khordha',
#        'sundargarh', 'pondicherry', 'barnala', 'fatehgarh sahib',
#        'muktsar', 'nawanshahr', 's.a.s nagar(mohali)',
#        'shaheed bhagat singh nagar', 'chittaurgarh', 'deeg', 'andamans',
#        'south andaman', 'k.v.rangareddy', 'karim nagar', 'mahabub nagar',
#        'anjaw', 'changlang', 'east siang', 'kamle', 'longding',
#        'west siang', 'biswanath', 'majuli', 'sribhumi',
#        'tamulpur district', 'west karbi anglong', 'banda', 'bulandshahar',
#        'chitrakoot', 'kushinagar *', 'sant ravidas nagar bhadohi',
#        'hardwar', 'alipurduar', 'bardhaman', 'darjiling',
#        'east midnapore', 'haora', 'hugli', 'koch bihar', 'maldah',
#        'north dinajpur', 'north twenty four parganas', 'purulia',
#        'south dinajpur', 'south twenty four parganas', 'west midnapore',
#        'north and middle andaman', 'north sikkim', 'south',
#        'south sikkim', 'west', 'chengalpattu', 'mayiladuthurai',
#        'perambalur', 'thiruvallur', 'medchal−malkajgiri',
#        'rajanna sircilla', 'rangareddy', 'gomati', 'sepahijala',
#        'barabanki', 'namsai', 'tirap', 'upper subansiri', 'bajali',
#        'chirang', 'pashchim champaran', 'samstipur',
#        'sarangarh-bilaigarh', 'east kameng', 'kurung kumey',
#        'lower siang', 'lower subansiri', 'papum pare', 'aurangabad(bh)',
#        'janjgir champa', 'jyotiba phule nagar', 'mahrajganj',
#        'lahul and spiti', 'reasi', 'shupiyan', 'bengaluru south',
#        'chamrajnagar', 'east sikkim', 'namchi', 'north', 'dhalai  *',
#        'kasargod', 'lakshadweep', 'chatrapati sambhaji nagar',
#        'east garo hills', 'eastern west khasi hills', 'lawngtlai', 'phek',
#        'wokha', 'subarnapur', 'dhaulpur', 'jhunjhunu', 'siang', 'monghyr',
#        'dadra & nagar haveli', 'jangaon', 'warangal (urban)',
#        'nandurbar *', 'raigarh(mh)', 'washim *', 'ukhrul',
#        'south west khasi hills', 'saitual', 'niuland', 'tuensang',
#        'nicobar', 'pashchimi singhbhum', 'sahibganj', 'haveri *',
#        'bagalkot *', 'yanam', 'dibang valley', 'lower dibang valley',
#        'bagpat', 'garhwal', 'kakching', 'chamarajanagar *', 'medinipur',
#        'mangan', 'dima hasao', 'janjgir - champa', 'narayanpur',
#        'lahul & spiti', 'leparada', 'shi-yomi', 'lahaul and spiti',
#        'khawzawl', 'noklak', 'south 24 pargana', 'west medinipur',
#        'shamator', 'tirupathur', 'east midnapur',
#        'mohalla-manpur-ambagarh chowki', 'kanchipuram', 'jaintia hills',
#        'bhabua', 'bardez', 'bengaluru rural', 'hawrah', 'hooghiy',
#        'pherzawl', 'jajapur  *', 'rajauri', 'jalore', 'salumbar',
#        'nicobars', 'beawar', 'didwana-kuchaman', 'kotputli-behror',
#        'phalodi', 'pakke kessang', 'hnahthial', 'balotra', 'leh (ladakh)',
#        'khairthal-tijara', 'ahilyanagar', 'tiswadi', 'south dumdum(m)',
#        'raebareli', 'dist : thane', 'balianta', 'bally jagachha',
#        'baghpat *', 'mohali', 'south  twenty four parganas', 'domjur',
#        'bicholim', 'naihati anandabazar', 'anugal', 'udham singh nagar *',
#        'poonch', 'kangpokpi', 'near meera hospital', 'tuticorin',
#        'hingoli *', 'tiruvarur', 'udupi *', 'jyotiba phule nagar *',
#        'bhadrak(r)', 'chitrakoot *', 'chandauli *', 'bijapur(kar)',
#        'bandipur', 'medchalâ\x88\x92malkajgiri'], dtype=object)

# %%
df['district_clean'].value_counts()
# Out:
# district_clean
# pune                  9634
# northparganas         9559
# thrissur              9496
# barddhaman            9361
# eastgodavari          8967
#                       ...
# balianta                 1
# naihatianandabazar       1
# nearmeerahospital        1
# bijapurkar               1
# bandipur                 1
# Name: count, Length: 916, dtype: int64

# %%
df['district_clean'] = df['district'].str.lower().str.strip().str.replace(r'[^a-z]', '', regex = True)

# %%
df['district_clean'] = df['district_clean'].str.replace(r'\s+', ' ', regex = True)

# %%
import unicodedata

df['district_clean'] = (df['district'].astype(str).apply(lambda x: unicodedata.normalize('NFKD', x)))

# to fix the encoded hypen in a the last district name

# %%
df['district_clean'] = (df['district_clean'].str.replace(r'\*', '', regex = True).str.replace(r'\(.*?\)','', regex = True))
# to remove the unnecessary stuff (i.e '*' and '(r)') from district names

# %%
df['district_clean'] = (df['district_clean'].str.replace(r'[-–—]', ' ', regex = True))
# fixes hyphens , dashes, spaces etc

# %%
df['district_clean'] = (df['district_clean'].str.replace(r'[^a-z\s]', '', regex = True).str.replace(r'\s+', ' ', regex = True))
# removes numbers , special characters from district names if any

# %%
district_replacements = {
    "belgaum": "belagavi",
    "mysore": "mysuru",
    "kancheepuram": "kanchipuram",
    "tuticorin": "thoothukudi",
    "bardhaman": "purba bardhaman",
    "west bardhaman": "paschim bardhaman",
    "jyotiba phule nagar": "amroha",
    "anugul": "angul"
}

df['district_clean'] = df['district_clean'].replace(district_replacements)

# %%
df = df[df['district_clean'].str.split().str.len() <= 3]

# %%
df['district_clean'].unique()
# Out:
# array(['gorakhpur', 'chittoor', 'rajkot', 'srikakulam', 'udaipur',
#        'sikar', 'tumakuru', 'kurnool', 'paschim medinipur', 'ghazipur',
#        'patan', 'mulugu', 'ganganagar', 'nayagarh', 'nashik',
#        'shivamogga', 'thrissur', 'hassan', 'patna', 'belagavi',
#        'kanchipuram', 'jabalpur', 'chennai', 'tinsukia', 'jamui', 'gaya',
#        'bengaluru', 'tiruppur', 'jalgaon', 'dhalai', 'nabarangapur',
#        'chittorgarh', 'darbhanga', 'purnia', 'muzaffarnagar', 'jaipur',
#        'churu', 'bharatpur', 'jamnagar', 'howrah', 'ahmedabad',
#        'west kameng', 'jalor', 'bahraich', 'nagapattinam', 'sheikhpura',
#        'amritsar', 'mysuru', 'alluri sitharama raju', 'sitamarhi',
#        'khunti', 'saharanpur', 'kanyakumari', 'prakasam', 'ananthapuramu',
#        'hooghly', 'central delhi', 'deoria', 'giridih', 'koraput',
#        'shahjahanpur', 'chhotaudepur', 'jalandhar', 'kannauj',
#        'visakhapatnam', 'jodhpur', 'karimnagar', 'amethi', 'hyderabad',
#        'salem', 'cuddalore', 'sabarkantha', 'kolar', 'nagpur',
#        'porbandar', 'chandigarh', 'paschim bardhaman', 'devbhumi dwarka',
#        'nalgonda', 'tawang', 'muzaffarpur', 'ganjam', 'kawardha',
#        'east godavari', 'dhanbad', 'gandhinagar', 'puruliya',
#        'siddharthnagar', 'bara banki', 'saran', 'hardoi',
#        'south parganas', 'ambedkar nagar', 'tiruchirappalli', 'indore',
#        'tiruvannamalai', 'kasaragod', 'mumbai', 'gopalganj',
#        'surendra nagar', 'annamayya', 'dindigul', 'narayanpet', 'tenkasi',
#        'mahesana', 'north east delhi', 'firozpur', 'araria', 'auraiya',
#        'krishnagiri', 'betul', 'satna', 'sangareddy', 'dahod',
#        'prayagraj', 'katihar', 'anakapalli', 'pratapgarh', 'kallakurichi',
#        'tikamgarh', 'bhojpur', 'jammu', 'khargone', 'aizawl', 'dholpur',
#        'kheda', 'madhubani', 'nawada', 'solapur', 'mayurbhanj', 'rewa',
#        'sambalpur', 'tiruvallur', 'bokaro', 'dakshina kannada',
#        'purba medinipur', 'north parganas', 'peren', 'kangra',
#        'kendrapara', 'palghar', 'erode', 'malappuram', 'rajouri',
#        'north goa', 'balrampur', 'surat', 'south delhi', 'khammam',
#        'kendujhar', 'ludhiana', 'coimbatore', 'rae bareli', 'amravati',
#        'krishna', 'bhadrak', 'parbhani', 'valsad', 'azamgarh',
#        'chhatarpur', 'amroha', 'jalna', 'parvathipuram manyam', 'sirmaur',
#        'west godavari', 'kv rangareddy', 'vijayapura', 'unakoti',
#        'virudhunagar', 'vadodara', 'sonipat', 'sultanpur', 'nadia',
#        'warangal', 'udupi', 'baramula', 'kalaburagi', 'nandyal',
#        'ernakulam', 'south west delhi', 'murshidabad',
#        'east jaintia hills', 'mandya', 'bijapur', 'gonda', 'kannur',
#        'mainpuri', 'medchal malkajgiri', 'jajpur', 'moradabad',
#        'namakkal', 'davangere', 'ganderbal', 'alappuzha', 'arvalli',
#        'rohtak', 'samastipur', 'medak', 'ahmadnagar', 'ratnagiri',
#        'chamrajanagar', 'buxar', 'mumbai suburban', 'nagarkurnool',
#        'charaideo', 'peddapalli', 'west champaran', 'cuddapah',
#        'khagaria', 'pune', 'chhindwara', 'east champaran', 'udalguri',
#        'nalbari', 'varanasi', 'chitradurga', 'adilabad', 'karimganj',
#        'nagaon', 'kolkata', 'gurgaon', 'east singhbhum', 'jajapur',
#        'agar malwa', 'gwalior', 'bijnor', 'kaithal', 'vellore', 'ballari',
#        'bankura', 'gulbarga', 'ramanathapuram', 'chumukedima',
#        'firozabad', 'barddhaman', 'farrukhabad', 'hisar',
#        'sri muktsar sahib', 'basti', 'baleswar', 'chikkaballapur',
#        'uttara kannada', 'botad', 'jalpaiguri', 'vizianagaram',
#        'dhenkanal', 'jaunpur', 'umaria', 'warangal rural', 'panchkula',
#        'kakinada', 'pithoragarh', 'pathanamthitta', 'palnadu',
#        'maharajganj', 'latehar', 'srinagar', 'badgam', 'buldhana',
#        'bikaner', 'moga', 'kaushambi', 'alwar', 'satara', 'damoh', 'puri',
#        'chamba', 'khorda', 'morbi', 'tirunelveli', 'bundi', 'kathua',
#        'ananthapur', 'chikkamagaluru', 'maihar', 'sitapur', 'aligarh',
#        'bagalkot', 'lakhimpur', 'kodagu', 'rajsamand', 'villupuram',
#        'karbi anglong', 'gajapati', 'shajapur', 'anantnag', 'karnal',
#        'guna', 'kheri', 'kachchh', 'purba bardhaman', 'angul',
#        'chandrapur', 'koppal', 'west garo hills', 'vikarabad', 'mau',
#        'churachandpur', 'dehradun', 'saharsa', 'sonbhadra', 'jhalawar',
#        'hoshangabad', 'baloda bazar', 'pulwama', 'tumkur', 'nuapada',
#        'aurangabad', 'rupnagar', 'sehore', 'bulandshahr', 'hanumakonda',
#        'narsinghpur', 'rohtas', 'fatehpur', 'jogulamba gadwal', 'n t r',
#        'osmanabad', 'daman', 'ajmer', 'dharmapuri', 'garhwa', 'pali',
#        'goalpara', 'ayodhya', 'anand', 'hailakandi', 'kozhikode', 'mandi',
#        'mandsaur', 'raichur', 'eluru', 'kasganj', 'kabeerdham',
#        'tehri garhwal', 'south goa', 'faizabad', 'gadag', 'baleshwar',
#        'dausa', 'siddipet', 'nagaur', 'ariyalur', 'ballia',
#        'kanpur nagar', 'neemuch', 'guntur', 'yavatmal', 'niwari',
#        'bharuch', 'uttar dinajpur', 'munger', 'east nimar', 'latur',
#        'ambala', 'bathinda', 'ramban', 'lucknow', 'nandurbar', 'theni',
#        'bhadradri kothagudem', 'nainital', 'bhopal', 'tirupattur',
#        'mahabubnagar', 'barpeta', 'cuttack', 'jashpur', 'gir somnath',
#        'kolhapur', 'datia', 'jhunjhunun', 'junagadh', 'seoni', 'agra',
#        'thane', 'rewari', 'bilaspur', 'raigarh', 'thiruvarur', 'jhajjar',
#        'sant kabir nagar', 'jagitial', 'anantapur', 'karur', 'arwal',
#        'shrawasti', 'golaghat', 'ujjain', 'sirohi', 'samba', 'nizamabad',
#        'bhilwara', 'darjeeling', 'marigaon', 'rajgarh', 'lohardaga',
#        'akola', 'pudukkottai', 'siwan', 'patiala', 'katni', 'sivaganga',
#        'budgam', 'kamrup metro', 'kapurthala', 'beed', 'banaskantha',
#        'sonitpur', 'tonk', 'bhadohi', 'dibrugarh', 'sangrur',
#        'thiruvananthapuram', 'narmadapuram', 'jorhat', 'hanumangarh',
#        'barwani', 'birbhum', 'dhule', 'gadag ', 'malda', 'kanker',
#        'yadadri', 'ghaziabad', 'cachar', 'lalitpur', 'bastar', 'boudh',
#        'bhiwani', 'mandla', 'ri bhoi', 'simdega', 'janjgir champa',
#        'jagatsinghapur', 'baksa', 'dohad', 'sas nagar ', 'dharwad',
#        'meerut', 'mathura', 'shivpuri', 'gumla', 'uttarkashi', 'banswara',
#        'bapatla', 'kanniyakumari', 'burhanpur', 'allahabad', 'bellary',
#        'fazilka', 'kaimur ', 'kamareddy', 'etah', 'etawah', 'vaishali',
#        'gautam buddha nagar', 'haridwar', 'dhar', 'balangir', 'hathras',
#        'sibsagar', 'rangareddi', 'nanded', 'bongaigaon', 'bandipore',
#        'chamoli', 'imphal east', 'jind', 'kota', 'udham singh nagar',
#        'north west delhi', 'champawat', 'shahdol', 'una', 'sirsa',
#        'mewat', 'suryapet', 'faridabad', 'east delhi', 'gurdaspur',
#        'mahasamund', 'baran', 'sri sathya sai', 'surguja', 'raipur',
#        'balaghat', 'yamuna nagar', 'madurai', 'shahdara', 'rampur',
#        'kupwara', 'dindori', 'kulgam', 'gadchiroli', 'north delhi',
#        'mumbai city', 'haveri', 'west delhi', 'barmer', 'balod',
#        'ferozepur', 'sagar', 'hoshiarpur', 'koriya', 'bareilly', 'punch',
#        'raisen', 'mahendragarh', 'serchhip', 'pauri garhwal',
#        'kurukshetra', 'anuppur', 'fatehabad', 'durg', 'korba', 'vidisha',
#        'dewas', 'ratlam', 'kolasib', 'ramanagar', 'doda', 'ashok nagar',
#        'mungeli', 'rajnandgaon', 'viluppuram', 'sidhi', 'bidar', 'jhansi',
#        'bhavnagar', 'jhabua', 'puducherry', 'charkhi dadri', 'tirupati',
#        'harda', 'y s r', 'bhind', 'tarn taran', 'yadgir',
#        'bangalore rural', 'vijayanagara', 'raigad', 'kokrajhar', 'shimla',
#        'pilibhit', 'west sikkim', 'alirajpur', 'palamu', 'karauli',
#        'deoghar', 'nellore', 'sindhudurg', 'chickmagalur', 'hamirpur',
#        'jharsuguda', 'begusarai', 'washim', 'kargil', 'dumka',
#        'pathankot', 'kalahandi', 'shamli', 'mahoba', 'panna', 'bageshwar',
#        'dhamtari', 'navsari', 'palakkad', 'sundergarh', 'sambhal',
#        'wayanad', 'sahebganj', 'sant ravidas nagar', 'nalanda',
#        'rayagada', 'dhubri', 'west khasi hills', 'almora', 'sangli',
#        'solan', 'rudraprayag', 'bangalore', 'supaul', 'khowai', 'darrang',
#        'jangoan', 'kanpur dehat', 'gariyaband', 'jehanabad', 'singrauli',
#        'kodarma', 'thanjavur', 'mahbubnagar', 'hazaribagh', 'east',
#        'debagarh', 'panchmahals', 'west tripura', 'amreli',
#        'west singhbhum', 'madhepura', 'baghpat', 'sonapur', 'dhemaji',
#        'seraikela kharsawan', 'zunheboto', 'bhagalpur', 'kushinagar',
#        'kalimpong', 'jhargram', 'lakhisarai', 'tapi', 'gondiya',
#        'east khasi hills', 'chhatrapati sambhajinagar', 'sawai madhopur',
#        'jaisalmer', 'ranchi', 'mancherial', 'mirzapur', 'cooch behar',
#        'senapati', 'karaikal', 'bemetara', 'budaun', 'hojai', 'godda',
#        'kottayam', 'uttar bastar kanker', 'thoothukkudi', 'dimapur',
#        'unnao', 'kondagaon', 'faridkot', 'tamenglong', 'bargarh',
#        'khandwa', 'hasan', 'chatra', 'jalaun', 'dakshin dinajpur',
#        'mahisagar', 'kollam', 'south tripura', 'shimoga', 'the dangs',
#        'nirmal', 'hapur', 'malkangiri', 'thoubal', 'lohit',
#        'gaurela pendra marwahi', 'komaram bheem', 'west nimar',
#        'north tripura', 'banka', 'lunglei', 'dungarpur', 'wanaparthy',
#        'bishnupur', 'kandhamal', 'mamit', 'south salmara mankachar',
#        'morena', 'north cachar hills', 'medchalmalkajgiri', 'kra daadi',
#        'surajpur', 'mahabubabad', 'mansa', 'udhampur', 'narsimhapur',
#        'saiha', 'sukma', 'jiribam', 'ranipet', 'chandauli', 'panipat',
#        'koderma', 'the nilgiris', 'idukki', 'kamrup',
#        'jayashankar bhupalpally', 'warangal urban', 'sheohar',
#        'upper siang', 'mauganj', 'diu', 'malerkotla', 'kiphire', 'palwal',
#        'khairagarh chhuikhadan gandai', 'kishtwar', 'wardha',
#        'kishanganj', 'sheopur', 'narmada', 'chamarajanagar',
#        'chikmagalur', 'davanagere', 'leh', 'harda ', 'pandhurna',
#        'ahmed nagar', 'bhandara', 'bid', 'buldana', 'dharashiv', 'gondia',
#        'gondiya ', 'hingoli', 'purba champaran', 'purnea', 'sheikpura',
#        'dakshin bastar dantewada', 'dantewada',
#        'manendragarh chirmiri bharatpur', 'sakti', 'najafgarh',
#        'new delhi', 'north east', 'south east delhi', 'ahmadabad',
#        'banas kantha', 'panch mahals', 'sabar kantha', 'surendranagar',
#        'yamunanagar', 'kinnaur', 'kullu', 'garhwa ', 'hazaribag',
#        'jamtara', 'pakaur', 'pakur', 'palamau', 'purbi singhbhum',
#        'ramgarh', 'chandel', 'imphal west', 'north garo hills',
#        'south garo hills', 'west jaintia hills', 'champhai', 'mammit',
#        'kohima', 'longleng', 'meluri', 'mokokchung', 'mon', 'tseminyu',
#        'baudh', 'jagatsinghpur', 'khordha', 'sundargarh', 'pondicherry',
#        'barnala', 'fatehgarh sahib', 'muktsar', 'nawanshahr', 'sas nagar',
#        'chittaurgarh', 'deeg', 'andamans', 'south andaman',
#        'kvrangareddy', 'karim nagar', 'mahabub nagar', 'anjaw',
#        'changlang', 'east siang', 'kamle', 'longding', 'west siang',
#        'biswanath', 'majuli', 'sribhumi', 'tamulpur district',
#        'west karbi anglong', 'banda', 'bulandshahar', 'chitrakoot',
#        'kushinagar ', 'hardwar', 'alipurduar', 'darjiling',
#        'east midnapore', 'haora', 'hugli', 'koch bihar', 'maldah',
#        'north dinajpur', 'purulia', 'south dinajpur', 'west midnapore',
#        'north sikkim', 'south', 'south sikkim', 'west', 'chengalpattu',
#        'mayiladuthurai', 'perambalur', 'thiruvallur', 'rajanna sircilla',
#        'rangareddy', 'gomati', 'sepahijala', 'barabanki', 'namsai',
#        'tirap', 'upper subansiri', 'bajali', 'chirang',
#        'pashchim champaran', 'samstipur', 'sarangarh bilaigarh',
#        'east kameng', 'kurung kumey', 'lower siang', 'lower subansiri',
#        'papum pare', 'mahrajganj', 'lahul and spiti', 'reasi', 'shupiyan',
#        'bengaluru south', 'chamrajnagar', 'east sikkim', 'namchi',
#        'north', 'dhalai ', 'kasargod', 'lakshadweep',
#        'chatrapati sambhaji nagar', 'east garo hills', 'lawngtlai',
#        'phek', 'wokha', 'subarnapur', 'dhaulpur', 'jhunjhunu', 'siang',
#        'monghyr', 'dadra nagar haveli', 'jangaon', 'warangal ',
#        'nandurbar ', 'washim ', 'ukhrul', 'saitual', 'niuland',
#        'tuensang', 'nicobar', 'pashchimi singhbhum', 'sahibganj',
#        'haveri ', 'bagalkot ', 'yanam', 'dibang valley',
#        'lower dibang valley', 'bagpat', 'garhwal', 'kakching',
#        'chamarajanagar ', 'medinipur', 'mangan', 'dima hasao',
#        'narayanpur', 'lahul spiti', 'leparada', 'shi yomi',
#        'lahaul and spiti', 'khawzawl', 'noklak', 'south pargana',
#        'west medinipur', 'shamator', 'tirupathur', 'east midnapur',
#        'jaintia hills', 'bhabua', 'bardez', 'bengaluru rural', 'hawrah',
#        'hooghiy', 'pherzawl', 'jajapur ', 'rajauri', 'jalore', 'salumbar',
#        'nicobars', 'beawar', 'didwana kuchaman', 'kotputli behror',
#        'phalodi', 'pakke kessang', 'hnahthial', 'balotra', 'leh ',
#        'khairthal tijara', 'ahilyanagar', 'tiswadi', 'south dumdum',
#        'raebareli', 'dist thane', 'balianta', 'bally jagachha',
#        'baghpat ', 'mohali', 'domjur', 'bicholim', 'naihati anandabazar',
#        'anugal', 'udham singh nagar ', 'poonch', 'kangpokpi',
#        'near meera hospital', 'thoothukudi', 'hingoli ', 'tiruvarur',
#        'udupi ', 'jyotiba phule nagar ', 'chitrakoot ', 'chandauli ',
#        'bandipur', 'medchalamalkajgiri'], dtype=object)

# %%
df.shape
# Out:
# (1583380, 14)

# %%
df.isnull().sum()
# Out:
# date                 0
# state                0
# district             0
# pincode              0
# age_5_17_count       0
# age_17_plus_count    0
# state_clean          0
# state_final          0
# total_updates        0
# day                  0
# month                0
# year                 0
# day_of_week          0
# district_clean       0
# dtype: int64

# %%
df = df[['date', 'state_final', 'district_clean', 'pincode', 'age_5_17_count','age_17_plus_count','total_updates', 'day', 'month','month','day_of_week']]

# %% [markdown]
# ### EDA and Visualization

# %%
plt.figure(figsize=(10,6))
sns.histplot(
    df['total_updates'],bins=30,stat='count',color='purple'
)
plt.title('Distribution of Total Demographic Updates')
plt.xlabel('Total Demographic Updates')
plt.ylabel('Count')
plt.show()

# %%
sns.barplot(df[['age_5_17_count','age_17_plus_count']], palette='Purples_r')
plt.title('Avg Demographic Updates by Age Group')
plt.xlabel('Age Groups')
plt.ylabel('Average Demographic Updates')
# Out:
# Text(0, 0.5, 'Average Demographic Updates')

# %%
# Daily updates tracking
daily_demo_updates = df.groupby('date')['total_updates'].sum().reset_index()
daily_demo_updates = pd.DataFrame(daily_demo_updates)
sns.lineplot(data=daily_demo_updates, x='date', y='total_updates', color='purple')
plt.title('Daily Demographic Updates Over Time')
plt.xticks(rotation=45)
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
# Analysing monthly updates trend
monthly_updates = df.groupby(['month'])['total_updates'].sum().reset_index()
monthly_updates = pd.DataFrame(monthly_updates)
monthly_updates.sort_values('total_updates', ascending=False)
# Out:
#    month  total_updates
# 0      3        8190152
# 8     12        7117729
# 7     11        7084261
# 5      9        5973224
# 6     10        3833130
# 4      7        1510892
# 3      6        1040944
# 2      5         939768
# 1      4         907282

# %%
sns.barplot(data = monthly_updates.sort_values(by='total_updates', ascending=False), x='month', y='total_updates', palette='Purples_r',hue = 'month', legend=False)
plt.title('Monthly Aadhaar updates')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
# weekly trends
df['day_of_week'] = df['date'].dt.day_name()
weekly_updates = df.groupby('day_of_week')['total_updates'].sum().reset_index()
weekly_updates = pd.DataFrame(weekly_updates)
weekly_updates.sort_values('total_updates', ascending=False)
# Out:
#   day_of_week  total_updates
# 2    Saturday       11519903
# 5     Tuesday        6169192
# 4    Thursday        4624281
# 0      Friday        4139600
# 1      Monday        3932667
# 6   Wednesday        3556332
# 3      Sunday        2655407

# %%
sns.barplot(data = weekly_updates.sort_values(by='total_updates', ascending=False), y='day_of_week', x='total_updates', palette='Purples_r', hue='day_of_week', legend=False)
# Out:
# <Axes: xlabel='total_updates', ylabel='day_of_week'>

# %%
# Which states have highest/lowest updates?
state_updates = df.groupby('state_final')['total_updates'].sum().reset_index()
state_updates = pd.DataFrame(state_updates)
state_updates = state_updates.sort_values(by='total_updates', ascending=False)
state_updates
# Out:
#                           state_final  total_updates
# 34                       uttarpradesh        6461558
# 20                        maharashtra        3824891
# 4                               bihar        3638841
# 35                         westbengal        2844291
# 19                      madhyapradesh        2104635
# 28                          rajasthan        2058897
# 30                          tamilnadu        1686874
# 1                       andhrapradesh        1547331
# 6                        chhattisgarh        1421369
# 10                            gujarat        1356661
# 31                          telangana        1329282
# 15                          karnataka        1254761
# 14                          jharkhand        1065263
# 8                               delhi         969666
# 25                             odisha         852623
# 11                            haryana         825843
# 3                               assam         755148
# 27                             punjab         650113
# 16                             kerala         573951
# 33                        uttarakhand         336374
# 13                    jammuandkashmir         294911
# 21                            manipur         233382
# 12                    himachalpradesh         115813
# 32                            tripura         104583
# 22                          meghalaya          63890
# 5                          chandigarh          49454
# 23                            mizoram          31556
# 2                    arunachalpradesh          28391
# 9                                 goa          27691
# 24                           nagaland          27555
# 26                         puducherry          25447
# 29                             sikkim          15216
# 7   dadraandnagarhavelianddamananddiu          10657
# 0            andamanandnicobarislands           5228
# 17                             ladakh           4323
# 18                        lakshadweep            913

# %%
dist_updates = df.groupby('district_clean')['total_updates'].sum().reset_index()
district_updates = pd.DataFrame(dist_updates)
district_updates = district_updates.sort_values(by='total_updates', ascending=False)

# %%
district_updates.head(10)
district_updates.tail(10)
# Out:
#            district_clean  total_updates
# 154            chandauli               1
# 383  jyotiba phule nagar               1
# 543    medchalamalkajgiri              1
# 64         bally jagachha              1
# 61               balianta              1
# 577   naihati anandabazar              1
# 236                domjur              1
# 232            dist thane              1
# 852             tiruvarur              1
# 865                udupi               1

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=state_updates, y='state_final', x='total_updates', palette='Purples_r')
plt.xlabel('Total Updates')
plt.ylabel('States')
plt.title('Aadhaar Updates by State')
# Out:
# C:\Users\Kimay\AppData\Local\Temp\ipykernel_21864\1244953112.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=state_updates, y='state_final', x='total_updates', palette='Purples_r')
# Text(0.5, 1.0, 'Aadhaar Updates by State')

# %%
df.head(2)
# Out:
#         date    state_final district_clean pincode  age_5_17_count  \
# 0 2025-03-01   uttarpradesh      gorakhpur  273213              49
# 1 2025-03-01  andhrapradesh       chittoor  517132              22
#
#    age_17_plus_count  total_updates  day  month  month day_of_week
# 0                529            578    1      3      3    Saturday
# 1                375            397    1      3      3    Saturday

# %%
# Pie chart of overall age-group share.
age_group_totals = df[['age_5_17_count',	'age_17_plus_count']].sum()
age_group_totals.plot.pie(autopct='%1.1f%%', colors=['#d1c4e9', '#7e57c2'], startangle=90)
plt.title('Overall Age Group Share in Aadhaar Updates')
# Out:
# Text(0.5, 1.0, 'Overall Age Group Share in Aadhaar Updates')
